# %%
import requests
import time

API_URL = "https://zotthytt12-hr-classifier.hf.space/rank"

payload = {
    "candidates": [
        {
            "identifier": "jan_kowalski",
            "Experience (Years)": 5,
            "Education": 3,
            "Certifications": 2,
            "Job Role": 4,
            "Salary Expectation ($)": 70000,
            "Projects Count": 6,
            "C++": 1,
            "Cybersecurity": 0,
            "Deep Learning": 1,
            "Ethical Hacking": 0,
            "Java": 1,
            "Linux": 1,
            "Machine Learning": 1,
            "NLP": 0,
            "Networking": 0,
            "Python": 1,
            "Pytorch": 0,
            "React": 0,
            "SQL": 1,
            "TensorFlow": 0
        }
    ]
}


try:
    response = requests.post(API_URL, json=payload)
    print("Status code:", response.status_code)
    print("Response:", response.text)
except requests.exceptions.SSLError:
    print("⚠️ Błąd SSL — spróbuj ponownie za minutę, certyfikat może się jeszcze odnawiać.")
# Out:
# Status code: 200
# Response: {"ranked_candidates":[{"identifier":"jan_kowalski","score":0.05}]}
